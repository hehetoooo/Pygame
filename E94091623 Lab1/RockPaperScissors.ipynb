# %%
from random import randint
print('Welcome to ROCK, PAPER, SCISSORS game!')

t =0
l = 0

while True:
    playermove = str(input('Enter your move: (r)ock (p)aper (s)cissors'))

    #player
    if playermove == 'r':
        playermove = 'Rock'
        playernum = 0;
        print('Rock versus...')   
    elif playermove == 'p':
        plplayermoveayermove = 'Paper'
        playernum = 1;
        print('Paper versus...')
    elif playermove == 's':
        playermove = 'Scissors'
        playernum = 2;
        print('Scissors versus...')
    else:
        print('Type error!')
        break
        
    #computer
    dice = randint(0, 2)
    
    if dice == 0:
        computermove = 'Rock'
    
    elif dice == 1:    
        computermove = 'Paper'
    
    elif dice == 2:
        computermove = 'Scissors'
    
    print(computermove)

    #result

    if playernum == dice:
        t = t + 1
        print('It is a tie!')

    elif playernum == 0 and dice == 1:
        l = l + 1
        print('You lose!')
    elif playernum == 1 and dice == 2:
        l = l + 1
        print('You lose!')
    elif playernum == 2 and dice == 0:
        l = l + 1
        print('You lose!')

    else:
        print('You win!')
        print('You have ',t,' ties and ',l,' losses before your first win.')
        break
